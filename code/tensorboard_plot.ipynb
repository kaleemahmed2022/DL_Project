# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)

    import os
    import sys
    os.chdir('/content/drive/MyDrive/DL_Project_GD/')
    sys.path.append('/content/drive/MyDrive/DL_Project_GD/code/')
except(ModuleNotFoundError):
    print('Initialising non-colab set-up... might not function here...')
    tpu_cores=None
    gpu_cores=None
    datapath = '../dataset/processed/'
    rootpath = '../'

print("datapath: {datapath}")
print('done.')

# %%
% load_ext tensorboard
% tensorboard --logdir ./VGGlogs/
