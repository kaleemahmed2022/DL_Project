# %%
print("DO NOT RUN WITH TPU/GPU unless necessary")
# Out:
# DO NOT RUN WITH TPU/GPU unless necessary

# %%
# !pip install pydub

# %%
try:
    print("Loading Colab setup")
    from google.colab import drive
    drive.mount('/content/drive')

    import os
    os.chdir('/content/drive/MyDrive/DL_Project/')
    m4apath = './minidata/raw/'
    sptpath = './minidata/processed/'
except(ModuleNotFoundError):
    print("Running outside of Collab")
    # first run preprocessing if needed
    m4apath = '../dataset/raw/'
    sptpath = '../dataset/processed/'

import preprocessing
# Out:
# Loading Colab setup
# Running outside of Collab

# %%
preprocessing.dataset_to_pt(m4apath, sptpath)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/Users/jameswilkinson/.conda/envs/DL_Project/lib/python3.9/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /Users/jameswilkinson/.conda/envs/DL_Project/lib/python3.9/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /Users/jameswilkinson/.conda/envs/DL_Project/lib/python3.9/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /Users/jameswilkinson/.conda/envs/DL_Project/lib/python3.9/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /Users/jameswilkinson/.conda/envs/DL_Project/lib/python3.9/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
# ...

# %%
preprocessing.gen_phases(sptpath, train_split=0.7, valid_split=0.15, test_split=0.15)
